# %%
import pandas as pd
import ast
import requests
import time

# %% [markdown]
# ## Reading saved data to python format

# %%
list_of_results = []

# %%
with open("results.txt", "r", encoding='utf-8') as file:
    for data in file.readlines():
        list_of_results.append(ast.literal_eval(data))

# %%
list_of_results
# Out:
# [('Warszawa, Białołęka, Nowodwory, Sprawna',
#   '365 065 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '50,34 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '5'],
#    ['Rok budowy', '2020']],
#   'https://www.otodom.pl/oferta/harmonogram-20-80-tarchomin-bezposredni-2020r-ID45Ys7.html#a2969c7ff8'),
#  ('Warszawa, Bemowo, Apenińska',
#   '450 000 zł',
#   ['Data dodania: 9 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '46,70 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1989'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/bemowo-po-generalnym-remoncie-ciche-ID462u3.html#8f74e2bbda'),
#  ('Warszawa, Żoliborz',
#   '420 000 zł',
#   ['Data dodania: około 11 godzin temu',
#    'Data aktualizacji: około 11 godzin temu'],
#   [['Powierzchnia', '34 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '> 10'],
#    ['Liczba pięter', '17'],
#    ['Rok budowy', '1967']],
#   'https://www.otodom.pl/oferta/zoliborz-34m2-2-pokoje-piekny-widok-metro-ID46bvh.html#1202492aa1'),
#  ('Warszawa, Żoliborz, Sady Żoliborskie',
#   '530 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: około 20 godzin temu'],
#   [['Powierzchnia', '46,60 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'inne'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1964'],
#    ['Stan wykończenia', 'do zamieszkania']],
#   'https://www.otodom.pl/oferta/mieszkanie-2-pokojowe-na-zielonym-zoliborzu-ID45Vq3.html#b34f478673'),
#  ('Warszawa, Mokotów, Górny Mokotów, al. Aleja Wilanowska',
#   'Zapytaj o cenę',
#   ['Data dodania: 15 dni temu', 'Data aktualizacji: 15 dni temu'],
#   [['Powierzchnia', '53,27 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'żelbet'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/nowe-mieszkanie-2-pokojowe-53-27-m2-z-balkonem-ID45XnI.html#d50d9768e5'),
#  ('Warszawa, Wola',
#   '735 000 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '59 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '6'],
#    ['Liczba pięter', '7'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '2019'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Czynsz', '530 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/3-pokoje-przy-forcie-wola-z-duzym-tarasem-ID45YJp.html#21ef5a94f7'),
#  ('Warszawa, Mokotów, Służewiec, Cybernetyki ',
#   '630 070 zł',
#   ['Data dodania: 13 dni temu', 'Data aktualizacji: 5 dni temu'],
#   [['Powierzchnia', '60,22 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '7'],
#    ['Materiał budynku', 'inne'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia']],
#   'https://www.otodom.pl/oferta/mieszkanie-trzypokojowe-na-sluzewcu-ID45YVY.html#b6d8ea0afc'),
#  ('Warszawa, Białołęka, Dąbrówka Szlachecka, ul. Przylesie',
#   '324 000 zł',
#   ['Data dodania: 15 dni temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '39 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1999'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '500 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/ciche-i-przytulne-m2-w-poblizu-parku-lesnego-ID45VL9.html#df03b3f48c'),
#  ('Warszawa, Targówek, Targówek Mieszkaniowy, Mokra 4',
#   '495 000 zł',
#   ['Data dodania: 3 dni temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '64 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1975'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '690 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/metro-trocka-3-pokoje-do-remontu-pelna-wlasnosc-ID468aK.html#767e8875cf'),
#  ('Warszawa, Ursynów',
#   '820 000 zł',
#   ['Data dodania: 11 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '76,50 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '12'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1985'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Czynsz', '640 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/mieszkanie-76-5-m2-dereniowa-ursynow-imielin-ID460Wc.html#2abfc73de4'),
#  ('Warszawa, Ursus, Skorosze, ul. Aleksandra Prystora',
#   '499 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '44,48 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2017'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '385 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/sprzedam-mieszkanie-44-5m-osiedle-skorosze-xi-ID45tSv.html#8adf2da82f'),
#  ('Warszawa, Wola, Górczewska 181/C.H. Wola Park',
#   '550 000 zł',
#   ['Data dodania: dzień temu', 'Data aktualizacji: około 18 godzin temu'],
#   [['Powierzchnia', '50 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2008'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/c-h-wola-park-ul-gorczewska-181-50m-3-pokoje-ID46aau.html#6bc969168d'),
#  ('Warszawa, Białołęka, ul. Zdziarska',
#   'Zapytaj o cenę',
#   ['Data dodania: ponad rok temu', 'Data aktualizacji: 5 dni temu'],
#   [['Powierzchnia', '81,56 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Rok budowy', '2020']],
#   'https://www.otodom.pl/oferta/mieszkanie-f2-m10-w-miasteczku-greenwood-ii-etap-ID3U7zm.html#95fc679861'),
#  ('Warszawa, Ochota, Juliana Ursyna Niemcewicza',
#   '1 000 000 zł',
#   ['Data dodania: 25 dni temu', 'Data aktualizacji: 25 dni temu'],
#   [['Powierzchnia', '92 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '6'],
#    ['Liczba pięter', '14'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2003'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/jasne-4-pokoje-108-5m2-6-pietro-2003-r-ochota-ID45MDS.html#035e3421b4'),
#  ('Warszawa, Śródmieście',
#   '1 015 000 zł',
#   ['Data dodania: 3 dni temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '60 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Rok budowy', '1937']],
#   'https://www.otodom.pl/oferta/metro-kamienica-gotowe-3mh-powisle-cicho-ID4690p.html#f11ce302e0'),
#  ('Warszawa, Mokotów',
#   '649 000 zł',
#   ['Data dodania: 3 miesiące temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '62,46 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '4'],
#    ['Rok budowy', '1937']],
#   'https://www.otodom.pl/oferta/pole-mokotowskiekamienicawysokie-3-1mm1-ID44OWG.html#df72cb01b2'),
#  ('Warszawa, Wawer, ul. Zwoleńska',
#   '539 500 zł',
#   ['Data dodania: ponad 2 lata temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '82,49 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'szeregowiec'],
#    ['Liczba pięter', '1'],
#    ['Materiał budynku', 'pustak'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-12-30']],
#   'https://www.otodom.pl/oferta/mieszkanie-82m2-duze-poddasze-wawer-bezposrednio-ID3oaKI.html#cc566114e5'),
#  ('Warszawa, Żoliborz, ul. Szamocka',
#   '630 000 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 11 dni temu'],
#   [['Powierzchnia', '44 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '6'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2016'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '549 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/warszawa-zoliborz-szamocka-44-m2-parking-gratis-ID45XOJ.html#21ef5a94f7'),
#  ('Warszawa, Ochota',
#   '396 500 zł',
#   ['Data dodania: 22 dni temu', 'Data aktualizacji: około 8 godzin temu'],
#   [['Powierzchnia', '26,30 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '6'],
#    ['Okna', 'drewniane'],
#    ['Rok budowy', '2011'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '280 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/komfortowa-kawalerka-przy-ul-wlodarzewskiej-ID45Pxs.html#db5604847d'),
#  ('Warszawa, Żoliborz',
#   '350 000 zł',
#   ['Data dodania: 24 dni temu', 'Data aktualizacji: 8 dni temu'],
#   [['Powierzchnia', '28,50 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1976'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '285 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/kawalerka-w-doskonalej-lokalizacji-ID45NL8.html#f7d6f0d1db'),
#  ('Warszawa, Praga-Południe',
#   '365 000 zł',
#   ['Data dodania: 2 miesiące temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '37 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1982'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '400 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe'],
#    ['Dostępne od', '2020-05-24']],
#   'https://www.otodom.pl/oferta/2-pokoje-z-garderoba-i-balkonem-ID45lpx.html#d060d6f98c'),
#  ('Warszawa, Ursus',
#   '359 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '44 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '7'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2021'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/2-pokoje-na-ursusie-cesja-ID45Cxj.html#c9042d66a4'),
#  ('Warszawa, Mokotów, Dolny Mokotów',
#   '2 900 000 zł',
#   ['Data dodania: 2 dni temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '165 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '7'],
#    ['Liczba pięter', '9'],
#    ['Materiał budynku', 'pustak'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2004'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '1 500 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/apartament-165m2-mokotow-ID46963.html#b99e5c6151'),
#  ('Warszawa, Praga-Południe, Jugosłowiańska',
#   '979 700 zł',
#   ['Data dodania: 4 miesiące temu', 'Data aktualizacji: około 11 godzin temu'],
#   [['Powierzchnia', '87 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '6'],
#    ['Rok budowy', '2011'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'spółdzielcze wł. z KW'],
#    ['Dostępne od', '2020-02-01']],
#   'https://www.otodom.pl/oferta/z-ogrodkiem-do-zamieszkania-ID44MvF.html#303312ddd3'),
#  ('Warszawa, Wilanów',
#   '585 300 zł',
#   ['Data dodania: 18 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '66,34 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '4'],
#    ['Rok budowy', '2021']],
#   'https://www.otodom.pl/oferta/prestizowe-osiedle-w-spokojnej-okolicy-ID45TkD.html#48ad27a9f5'),
#  ('Warszawa, Śródmieście',
#   '960 500 zł',
#   ['Data dodania: 10 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '41 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '> 10'],
#    ['Liczba pięter', '23'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '350 zł'],
#    ['Forma własności', 'spółdzielcze wł. z KW'],
#    ['Dostępne od', '2020-05-25']],
#   'https://www.otodom.pl/oferta/1-pokojowe-w-atrakcyjnej-lokalizacji-ID4619B.html#69d6470f5c'),
#  ('Warszawa, Wilanów',
#   '1 749 000 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '133 m²'],
#    ['Liczba pokoi', '5'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2019'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/penthouse-na-ostatnim-pietrze-ID45YPT.html#fbf07e4158'),
#  ('Warszawa, Białołęka',
#   '399 000 zł',
#   ['Data dodania: 4 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '53 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '2001'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '600 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/mieszkanie-53-m-warszawa-ID4679y.html#ac8d4ef149'),
#  ('Warszawa, Bemowo, Widawska',
#   '1 160 000 zł',
#   ['Data dodania: 10 miesięcy temu', 'Data aktualizacji: 11 dni temu'],
#   [['Powierzchnia', '117,51 m²'],
#    ['Liczba pokoi', '6'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1998'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '1 100 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/komfortowe-mieszkanie-dla-rodziny-ID424qA.html#39317506aa'),
#  ('Warszawa, Ursynów, Alternatywy',
#   '1 199 000 zł',
#   ['Data dodania: 10 dni temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '110 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '7'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2006'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '940 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/klimatyczne-mieszkanie-z-zacisznym-ogrodkiem-ID461nd.html#bdc3382d00'),
#  ('Warszawa, Mokotów',
#   '592 895 zł',
#   ['Data dodania: 9 dni temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '58,62 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '7'],
#    ['Rok budowy', '2020']],
#   'https://www.otodom.pl/oferta/osiedle-z-dogodna-komunikacja-mokotow-ID462WU.html#70655cb8f1'),
#  ('Warszawa, Białołęka, Odkryta',
#   '265 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '33 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'drewniane'],
#    ['Rok budowy', '1999'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '300 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/kawalerka-33m-2-wyposazona-i-wolna-od-zaraz-ID45yAe.html#30292817b0'),
#  ('Warszawa, Mokotów, Czerniakowska',
#   '469 000 zł',
#   ['Data dodania: 15 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '37 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '8'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1960'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '400 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/dwupokojowy-apartament-blisko-lazienek-ID45Xwt.html#3f37fca41d'),
#  ('Warszawa, Wola, Ogrodowa',
#   '939 000 zł',
#   ['Data dodania: 21 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '67 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '5'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1954']],
#   'https://www.otodom.pl/oferta/nowe-4-pokojowe-mieszkanie-na-mirowie-ID45Rdh.html#5178969d15'),
#  ('Warszawa, Praga-Południe, Grochów, ul. Przeworska',
#   'Zapytaj o cenę',
#   ['Data dodania: 22 dni temu', 'Data aktualizacji: około 20 godzin temu'],
#   [['Powierzchnia', '53,40 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '2'],
#    ['Rok budowy', '2022'],
#    ['Stan wykończenia', 'do wykończenia']],
#   'https://www.otodom.pl/oferta/mala-praga-f-022-ID45PCH.html#7ef0743e10'),
#  ('Warszawa, Praga-Południe, Gocław, Jana Nowaka-Jeziorańskiego',
#   '998 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 5 dni temu'],
#   [['Powierzchnia', '108,60 m²'],
#    ['Liczba pokoi', '5'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '14'],
#    ['Rok budowy', '2011'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2019-12-03']],
#   'https://www.otodom.pl/oferta/okazja-warszawa-goclaw-mieszkanie-108m2-ID45Dkl.html#b4526c03a9'),
#  ('Warszawa, Targówek, Bolesławicka',
#   '520 000 zł',
#   ['Data dodania: 11 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '54 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '8'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1974'],
#    ['Forma własności', 'spółdzielcze własnościowe'],
#    ['Dostępne od', '2020-05-25']],
#   'https://www.otodom.pl/oferta/54m2-na-brodnie-obok-parku-wysoki-standard-ID4612G.html#200f1ab875'),
#  ('Warszawa, Targówek, Bródno-Podgrodzie',
#   '2 100 000 zł',
#   ['Data dodania: 23 dni temu', 'Data aktualizacji: 23 dni temu'],
#   [['Powierzchnia', '137 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '4']],
#   'https://www.otodom.pl/oferta/unikatowy-apartament-na-mokotowie-ID45P3m.html#6710bf3150'),
#  ('Warszawa, Mokotów',
#   '725 500 zł',
#   ['Data dodania: 29 dni temu', 'Data aktualizacji: 29 dni temu'],
#   [['Powierzchnia', '58 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '2'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1950'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-05-06']],
#   'https://www.otodom.pl/oferta/klimatyczne-3-pokoje-w-swietnej-lokalizacji-ID45ImO.html#24de28efb0'),
#  ('Warszawa, Śródmieście, Przemysłowa 34',
#   '769 000 zł',
#   ['Data dodania: 5 miesięcy temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '46 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'pustak'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2019'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-01-14']],
#   'https://www.otodom.pl/oferta/bezposrednio-powisle-nowa-kamienica-46m2-2pok-ID44cp9.html#9e2c8ada2e'),
#  ('Warszawa, Białołęka, ul. Skarbka z Gór',
#   '445 000 zł',
#   ['Data dodania: około miesiąc temu',
#    'Data aktualizacji: około 21 godzin temu'],
#   [['Powierzchnia', '54,90 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2007'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-05-20']],
#   'https://www.otodom.pl/oferta/zamieszkaj-w-ciszy-w-dobrym-standardzie-ID45vP7.html#33599ece35'),
#  ('Warszawa, Śródmieście, Ptasia',
#   '655 000 zł',
#   ['Data dodania: 28 dni temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '55 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '5'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1994'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/kamienica-obok-hali-mirowskiej-ID45KkS.html#dcc56023e6'),
#  ('Warszawa, Białołęka, Głębocka 54',
#   '620 000 zł',
#   ['Data dodania: 13 dni temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '73 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2009'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '700 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/wygodne-jasne-i-nowoczesne-3-pokojowe-mieszkanie-ID45Z6x.html#94a8d7f5e0'),
#  ('Warszawa, Śródmieście',
#   '1 336 478 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '80,79 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '9'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/mieszkanie-z-tarasem-46-m2-i-metro-i-srodmiescie-ID45Y78.html#c98213f8d6'),
#  ('Warszawa, Wawer, ul. Zwoleńska',
#   '539 500 zł',
#   ['Data dodania: ponad 2 lata temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '82,49 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'szeregowiec'],
#    ['Liczba pięter', '1'],
#    ['Materiał budynku', 'pustak'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-12-30']],
#   'https://www.otodom.pl/oferta/mieszkanie-82m2-duze-poddasze-wawer-bezposrednio-ID3oaKI.html#a1dfbd67c0'),
#  ('Warszawa, Mokotów, Sielce, Czerska',
#   '635 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '56 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2008'],
#    ['Czynsz', '500 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/swietne-do-mieszkania-jak-i-na-inwestycje-ID45xaV.html#058ca66b61'),
#  ('Warszawa, Praga-Północ',
#   '299 999 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '30 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1934'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Czynsz', '360 zł']],
#   'https://www.otodom.pl/oferta/kamienica-metro-stan-deweloperski-widne-bez-pcc-ID45tDr.html#a36c1f0751'),
#  ('Warszawa, Mokotów, Biały Kamień',
#   '2 900 000 zł',
#   ['Data dodania: 4 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '162,30 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2008'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/ekskluzywny-apartament-z-tarasem-w-eco-parku-ID467zA.html#8559fb345e'),
#  ('Warszawa, Bielany',
#   '790 000 zł',
#   ['Data dodania: 4 miesiące temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '96 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1995'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '540 zł'],
#    ['Forma własności', 'spółdzielcze wł. z KW'],
#    ['Dostępne od', '2020-05-19']],
#   'https://www.otodom.pl/oferta/idealne-dla-rodziny-w-okazyjnej-cenie-ID44Eeo.html#bdc3382d00'),
#  ('Warszawa, Ochota, Opaczewska',
#   '600 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 5 dni temu'],
#   [['Powierzchnia', '55,30 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1999'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '470 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/ochota-szczesliwice-2-pokoje-balkon-1-pietro-ID45usw.html#cb9bfa58bc'),
#  ('Warszawa, Ursynów, Wyczółki, ul. Kłobucka',
#   '699 900 zł',
#   ['Data dodania: 20 dni temu', 'Data aktualizacji: 14 dni temu'],
#   [['Powierzchnia', '48,65 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'silikat'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2019'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '550 zł']],
#   'https://www.otodom.pl/oferta/nowe-swiezo-wykonczone-2-pok-48m2-ul-klobucka-ID45S0I.html#ab1bb35f8b'),
#  ('Warszawa, Ursynów, Jana Rosoła',
#   '540 000 zł',
#   ['Data dodania: 30 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '39,10 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2001'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/zamieszkaj-na-zielonym-ursynowie-blisko-metra-ID45HSh.html#62d245994e'),
#  ('Warszawa, Wola',
#   '970 000 zł',
#   ['Data dodania: 2 dni temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '86 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/dwu-stronne-dwa-tarasy-2-x-lazienka-garderoba-pral-ID469tm.html#d5e5082042'),
#  ('Warszawa, Bemowo',
#   '470 000 zł',
#   ['Data dodania: 3 miesiące temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '54 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'pustak'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2004'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-04-30']],
#   'https://www.otodom.pl/oferta/bemowo-nowe-gorce-2-pok-54m2-m-postojowe-komorka-ID44ZXn.html#3a897a9a18'),
#  ('Warszawa, Białołęka, ul. Białołęcka',
#   'Zapytaj o cenę',
#   ['Data dodania: 2 miesiące temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '67,06 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '3'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia']],
#   'https://www.otodom.pl/oferta/osiedle-viva-garden-10-mieszkanie-nr-65-ID45lOz.html#9899517db8'),
#  ('Warszawa, Wawer, ul. Zwoleńska',
#   '539 500 zł',
#   ['Data dodania: ponad 2 lata temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '82,49 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'szeregowiec'],
#    ['Liczba pięter', '1'],
#    ['Materiał budynku', 'pustak'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-12-30']],
#   'https://www.otodom.pl/oferta/mieszkanie-82m2-duze-poddasze-wawer-bezposrednio-ID3oaKI.html#af54bdeecb'),
#  ('Warszawa, Praga-Północ',
#   '295 000 zł',
#   ['Data dodania: 15 dni temu', 'Data aktualizacji: 15 dni temu'],
#   [['Powierzchnia', '30,03 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '6'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/bezposrednio-kawalerka-30m-mozliwosc-2pok-praga-ID45X3v.html#aefd63ae8f'),
#  ('Warszawa, Białołęka, ul. Ornecka',
#   '525 000 zł',
#   ['Data dodania: 21 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '105 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'dom wolnostojący'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '1'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia']],
#   'https://www.otodom.pl/oferta/tanie-segmenty-z-garazem-i-ogrodkiem-bonus-35m2-ID45Rc5.html#a9fafaa39d'),
#  ('Warszawa, Wilanów',
#   '469 000 zł',
#   ['Data dodania: 4 miesiące temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '40,65 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2016'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '460 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/41m2-wilanow-garaz-balkon-ID44nWY.html#7eb9806f12'),
#  ('Warszawa, Śródmieście',
#   '2 800 000 zł',
#   ['Data dodania: 24 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '103,83 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '> 10'],
#    ['Liczba pięter', '11'],
#    ['Okna', 'drewniane'],
#    ['Rok budowy', '2019'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/luksusowy-apartament-z-widokiem-na-panorame-miasta-ID45NtM.html#9abdd48bbc'),
#  ('Warszawa, Wilanów, al. Wilanowska',
#   '1 049 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '92,85 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'inne'],
#    ['Rok budowy', '2007'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '1 100 zł']],
#   'https://www.otodom.pl/oferta/apartament-3-pokoje-92-85m2-aleja-wilanowska-ID45Asj.html#5b36373c6e'),
#  ('Warszawa, Ursynów, Natolin',
#   '648 000 zł',
#   ['Data dodania: 10 dni temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '62 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1986'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '700 zł'],
#    ['Forma własności', 'spółdzielcze wł. z KW']],
#   'https://www.otodom.pl/oferta/bezposrednio-bardzo-ladne-mieszkanie-natoin-ID461DY.html#342a65b150'),
#  ('Warszawa, Mokotów, Eko-Park',
#   '1 530 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '118 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '7'],
#    ['Liczba pięter', '7'],
#    ['Rok budowy', '2006'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/eko-park118m2-poziomy2-tarasygaraz4-komorki-ID45qIu.html#8f74e2bbda'),
#  ('Warszawa, Wola, Muranów, Pamiętajcie o Ogrodach',
#   '919 366 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '77,46 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '9']],
#   'https://www.otodom.pl/oferta/3-pokoje-srodmiescie-pln-tuz-przy-metrze-ID45Ykd.html#33e12c567b'),
#  ('Warszawa, Praga-Południe, Gocław, ul. Międzyborska',
#   '690 000 zł',
#   ['Data dodania: 24 dni temu', 'Data aktualizacji: 14 dni temu'],
#   [['Powierzchnia', '67,20 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '7'],
#    ['Materiał budynku', 'silikat'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2011'],
#    ['Stan wykończenia', 'do zamieszkania']],
#   'https://www.otodom.pl/oferta/sa-takie-miejsca-do-ktorych-chcemy-wracac-67-2m2-ID45NeC.html#81f751cc4a'),
#  ('Warszawa, Mokotów',
#   '367 545 zł',
#   ['Data dodania: 5 miesięcy temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '30,96 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '10'],
#    ['Rok budowy', '2021']],
#   'https://www.otodom.pl/oferta/nowoczesne-osiedle-z-dogodna-komunikacja-warszawa-ID44gwS.html#4c50a19ce8'),
#  ('Warszawa, Bemowo, Jelonki, Powstańców Śląskich',
#   '537 000 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '55,80 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'inne'],
#    ['Rok budowy', '1947'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/dwupoziomowe-mieszkanie-w-kamienicy-po-remoncie-ID45vhR.html#95fc679861'),
#  ('Warszawa, Ursynów, Natolin, Meander',
#   '920 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '111 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '10'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1987'],
#    ['Czynsz', '1 200 zł'],
#    ['Forma własności', 'spółdzielcze wł. z KW']],
#   'https://www.otodom.pl/oferta/trzy-pokoje-metro-natolin-ID45WlP.html#3436b4173f'),
#  ('Warszawa, Targówek, Bródno, Krasiczyńska',
#   '340 000 zł',
#   ['Data dodania: 3 miesiące temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '26,50 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1972'],
#    ['Czynsz', '460 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/kawalerka-z-wydzielona-strefa-sypialniana-ID456tl.html#d7c9c74bf3'),
#  ('Warszawa, Mokotów',
#   '319 000 zł',
#   ['Data dodania: 18 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '31 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1980'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/kawalerka-mokotow-ID45TEz.html#759f46ff34'),
#  ('Warszawa, Mokotów, Górny Mokotów, al. Aleja Wilanowska',
#   'Zapytaj o cenę',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '89,30 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'żelbet'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/nowe-mieszkanie-4-pokojowe-89-30-m2-z-tarasem-ID45WQ7.html#c29d493f64'),
#  ('Warszawa, Rembertów',
#   '677 600 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '92 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '5'],
#    ['Rok budowy', '2020']],
#   'https://www.otodom.pl/oferta/prestizowa-inwestycja-na-wawrze-inna-niz-wszystkie-ID45WSP.html#c29d493f64'),
#  ('Warszawa, Mokotów',
#   '540 500 zł',
#   ['Data dodania: 21 dni temu', 'Data aktualizacji: 21 dni temu'],
#   [['Powierzchnia', '64 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Dostępne od', '2020-05-15']],
#   'https://www.otodom.pl/oferta/rozkladowe-4-pokoje-na-dolnym-mokotowie-ID45Rwp.html#fed2eecb58'),
#  ('Warszawa, Praga-Południe',
#   '539 400 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '58,40 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/warszawa-kwatery-glownej-46-c-2-pok-sprz-ID45Wq6.html#b41296de44'),
#  ('Warszawa, Praga-Południe, Gocław, al. J. Nowaka-Jeziorańskiego',
#   '562 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '60,10 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/sloneczne-od-zach-balkon-dobra-komunikacja-ID45VuC.html#e91cfa02f8'),
#  ('Warszawa, Śródmieście, Sienna',
#   '335 000 zł',
#   ['Data dodania: 7 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '22 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'żelbet'],
#    ['Stan wykończenia', 'do zamieszkania']],
#   'https://www.otodom.pl/oferta/atrakcyjna-lokalizacja-ID4657M.html#0c4a1dfcfe'),
#  ('Warszawa, Mokotów, Ludwiga van Beethovena',
#   '465 000 zł',
#   ['Data dodania: ponad rok temu', 'Data aktualizacji: 8 dni temu'],
#   [['Powierzchnia', '45,20 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '5'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2019-02-04']],
#   'https://www.otodom.pl/oferta/sloneczne-dobry-rozklad-2-pokoje-mokotow-ID3TY7S.html#e48d182570'),
#  ('Warszawa, Mokotów, Górny Mokotów, ul. Wiartel',
#   '470 000 zł',
#   ['Data dodania: 20 dni temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '56,20 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1970'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '570 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/okazja-4-pokoje-56-m2-na-mokotowie-ID45S3g.html#66b0717e85'),
#  ('Warszawa, Mokotów, Aleja Wilanowsaka',
#   '1 290 000 zł',
#   ['Data dodania: 8 dni temu', 'Data aktualizacji: 8 dni temu'],
#   [['Powierzchnia', '151 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '2008'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/mokotow-apartament-151m-niedaleko-metro-ID464mR.html#18278c6c79'),
#  ('Warszawa, Wola, Józefa Sowińskiego',
#   '750 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '58 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '7']],
#   'https://www.otodom.pl/oferta/mieszkanie-warszawa-wola-ID45Wm0.html#3436b4173f'),
#  ('Warszawa, Mokotów, Rajska',
#   '850 000 zł',
#   ['Data dodania: 7 miesięcy temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '75 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2014'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2019-10-29']],
#   'https://www.otodom.pl/oferta/ciche-trzy-pokoje-duzy-taras-marina-ID43qdZ.html#764ab93de5'),
#  ('Warszawa, Wola',
#   '385 000 zł',
#   ['Data dodania: 3 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '32,10 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1962'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '330 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/metro-cicho-i-zielono-kamienica-1-pietro-ID4683a.html#bb40013e62'),
#  ('Warszawa, Rembertów',
#   '649 900 zł',
#   ['Data dodania: 13 dni temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '132 m²'],
#    ['Liczba pokoi', '7'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2012'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-05-22']],
#   'https://www.otodom.pl/oferta/komfortowe-mieszkanie-warszawa-rembertow-132m2-ID45YWj.html#86ecbd8815'),
#  ('Warszawa, Mokotów',
#   '370 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '32 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Ogrzewanie', 'inne']],
#   'https://www.otodom.pl/oferta/32m2-na-mokotowie-ID45WxD.html#c411e5b992'),
#  ('Warszawa, Mokotów, Górny Mokotów, Juliana Fałata',
#   '2 300 000 zł',
#   ['Data dodania: 18 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '124,40 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '3'],
#    ['Rok budowy', '2004'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/wyjatkowy-apartament-na-sprzedaz-starym-mokotow-ID45Thr.html#aefd63ae8f'),
#  ('Warszawa, Praga-Południe',
#   '490 000 zł',
#   ['Data dodania: 10 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '63,30 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '7'],
#    ['Liczba pięter', '8'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1982'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '549,11 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/trzypokojowe-na-warszawskim-goclawiu-ID4617k.html#3a3d361042'),
#  ('Warszawa, Wola',
#   '988 000 zł',
#   ['Data dodania: 23 dni temu', 'Data aktualizacji: 8 dni temu'],
#   [['Powierzchnia', '55,22 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '5'],
#    ['Okna', 'drewniane'],
#    ['Rok budowy', '2018'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Czynsz', '450 zł']],
#   'https://www.otodom.pl/oferta/zamkniete-nowoczesne-osiedle-przy-krochmalnej-ID45OmT.html#9d8f79da40'),
#  ('Warszawa, Mokotów, Siekierki, Ananasowa',
#   '525 000 zł',
#   ['Data dodania: 27 dni temu', 'Data aktualizacji: około 7 godzin temu'],
#   [['Powierzchnia', '44,94 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2018'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/2-pok-balkon-winda-garaz-mokotow-ul-ananasowa-ID45KvZ.html#50112acfd5'),
#  ('Warszawa, Wilanów, Wiktorii Wiedeńskiej',
#   '750 000 zł',
#   ['Data dodania: 30 dni temu', 'Data aktualizacji: 30 dni temu'],
#   [['Powierzchnia', '85 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '4'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1989'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '700 zł']],
#   'https://www.otodom.pl/oferta/mieszkanie-85-m-warszawa-ID45I4N.html#a535ccc826'),
#  ('Warszawa, Białołęka, ul. Winorośli',
#   'Zapytaj o cenę',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '69,22 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '5']],
#   'https://www.otodom.pl/oferta/osiedle-przystanek-tarchomin-1-mieszkanie-64-ID45uZG.html#3f23cd058f'),
#  ('Warszawa, Praga-Południe, Gocław, Ostrobramska',
#   '473 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 17 dni temu'],
#   [['Powierzchnia', '44,96 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '6'],
# ...
#  ('Warszawa, Ursus, ul. Traktorzystów',
#   '463 945,3 zł',
#   ['Data dodania: 2 miesiące temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '63,67 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '6'],
#    ['Rok budowy', '2021'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/ursus-factory-3-mieszkanie-trzypokojowe-nr-77-ID45kDg.html#9be2392d62'),
#  ('Warszawa, Praga-Północ',
#   '383 600 zł',
#   ['Data dodania: 8 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '38,80 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '6'],
#    ['Liczba pięter', '6'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'aluminiowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/praga-polnoc-ul-ks-i-klopotowskiego-przy-wisle-ID464Bv.html#340b4adcde'),
#  ('Warszawa, Białołęka, ul. Cieślewskich',
#   '391 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '64,02 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rok budowy', '2020']],
#   'https://www.otodom.pl/oferta/ogrody-przyjaciol-4-dom-nr-20a-ID45nmz.html#529c973472'),
#  ('Warszawa, Ursynów, Wyczółki, ul. Kłobucka',
#   '564 000 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '44,02 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'silikat'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2019'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '350 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/tylko-2-tyg-cena-nizsza-o-25-tys-zl-ul-klobucka-ID45YLp.html#08918dd4dd'),
#  ('Warszawa, Targówek, Targówek Mieszkaniowy',
#   '470 000 zł',
#   ['Data dodania: 24 dni temu', 'Data aktualizacji: 18 dni temu'],
#   [['Powierzchnia', '53,30 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1976'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '680 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/mieszkanie-na-sprzedaz-warszawa-targowek-ID45MVn.html#a02099d235'),
#  ('Warszawa, Mokotów',
#   '429 900 zł',
#   ['Data dodania: 15 dni temu', 'Data aktualizacji: 4 dni temu'],
#   [['Powierzchnia', '31,06 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '6'],
#    ['Liczba pięter', '10'],
#    ['Materiał budynku', 'wielka płyta'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1970'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '315 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/2-pokoje-po-generalnym-remoncie-ID45VNb.html#e3185f0935'),
#  ('Warszawa, Żoliborz, Bitwy pod Rokitną',
#   '2 900 000 zł',
#   ['Data dodania: 22 dni temu', 'Data aktualizacji: 3 dni temu'],
#   [['Powierzchnia', '140 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '9'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2002'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '1 700 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/luksus-komfort-i-bezpieczenstwo-ID45Qrl.html#bab18874ff'),
#  ('Warszawa, Bemowo',
#   '499 999 zł',
#   ['Data dodania: 2 dni temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '60 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '11'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1986'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2020-06-03']],
#   'https://www.otodom.pl/oferta/przestronne-mieszkanie-z-oddzielna-kuchnia-ID469id.html#175b6d408f'),
#  ('Warszawa, Wola',
#   '550 000 zł',
#   ['Data dodania: 28 dni temu', 'Data aktualizacji: 22 dni temu'],
#   [['Powierzchnia', '48 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '3'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '560 zł'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/mieszkania-48m2-bliska-wola-ID45Kfn.html#ec10aa01a6'),
#  ('Warszawa, Żoliborz, Gwiaździsta',
#   '688 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '56,80 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '9'],
#    ['Liczba pięter', '11'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2008'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/apartament-na-kepie-potockiej-z-widokiem-na-park-ID45qQ7.html#03195186b8'),
#  ('Warszawa, Mokotów',
#   '920 000 zł',
#   ['Data dodania: 3 dni temu', 'Data aktualizacji: około 10 godzin temu'],
#   [['Powierzchnia', '73,50 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '11'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1985'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '750 zł'],
#    ['Forma własności', 'spółdzielcze wł. z KW']],
#   'https://www.otodom.pl/oferta/mokotow-sluzew-nad-dolinka-ID468GS.html#2c453c49c1'),
#  ('Warszawa, Śródmieście',
#   '870 000 zł',
#   ['Data dodania: 8 dni temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '67,46 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1937'],
#    ['Czynsz', '690 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/zlota2-balkonykamienica-z-windapalac-kultury-ID464uL.html#deef281545'),
#  ('ul. Zgrupowania AK "Żmija", Warszawa, mazowieckie',
#   '995 000 zł',
#   ['Data dodania: 16 dni temu', 'Data aktualizacji: 16 dni temu'],
#   [['Powierzchnia', '101 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2002'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '1 000 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/przestronne-3-pokojowe-z-duza-kuchnia-i-jadalnia-ID45V9K.html#10b6ea66b7'),
#  ('Warszawa, Wilanów, Zawady',
#   '580 800 zł',
#   ['Data dodania: 10 dni temu', 'Data aktualizacji: 10 dni temu'],
#   [['Powierzchnia', '61,30 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Czynsz', '9 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/wilanow-zawady-3-pok-61-30m2-ogrodek-58-m2-nowe-0-ID461ET.html#6ca7e381ab'),
#  ('Warszawa, Żoliborz, ul. Szamocka',
#   '630 000 zł',
#   ['Data dodania: 14 dni temu', 'Data aktualizacji: 11 dni temu'],
#   [['Powierzchnia', '44 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '6'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2016'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '549 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/warszawa-zoliborz-szamocka-44-m2-parking-gratis-ID45XOJ.html#fd949845df'),
#  ('Warszawa, Bemowo, ul. Grodkowska',
#   'Zapytaj o cenę',
#   ['Data dodania: 23 dni temu', 'Data aktualizacji: 21 dni temu'],
#   [['Powierzchnia', '80,89 m²'],
#    ['Liczba pokoi', '4'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '8'],
#    ['Rok budowy', '2021'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/esteio-mieszkanie-a401-ID45OiJ.html#6ba13ac97d'),
#  ('Warszawa, Wola, Juliana Konstantego Ordona',
#   '513 345 zł',
#   ['Data dodania: dzień temu', 'Data aktualizacji: około godziny temu'],
#   [['Powierzchnia', '46,72 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Piętro', 'parter'],
#    ['Liczba pięter', '8'],
#    ['Rok budowy', '2021'],
#    ['Dostępne od', '2021-12-31']],
#   'https://www.otodom.pl/oferta/swietne-przestronne-i-jasne-ogrodek-i-taras-ID46afV.html#110fc9e58d'),
#  ('Warszawa, Praga-Południe, Gocław, Łukowska',
#   '911 200 zł',
#   ['Data dodania: około miesiąc temu', 'Data aktualizacji: 5 dni temu'],
#   [['Powierzchnia', '108 m²'],
#    ['Liczba pokoi', '5'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '3'],
#    ['Liczba pięter', '3'],
#    ['Rok budowy', '2000'],
#    ['Forma własności', 'spółdzielcze własnościowe']],
#   'https://www.otodom.pl/oferta/rozkladowe-ciche-2-loggie-widok-na-zielen-ID45DjK.html#b4526c03a9'),
#  ('Warszawa, Wilanów',
#   '529 400 zł',
#   ['Data dodania: 21 dni temu', 'Data aktualizacji: 21 dni temu'],
#   [['Powierzchnia', '56,72 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '2'],
#    ['Materiał budynku', 'inne'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/wyjatkowy-projekt-na-zawadach-urokliwa-okolica-ID45RcC.html#5178969d15'),
#  ('Warszawa, Wola, ul. Obozowa',
#   '280 000 zł',
#   ['Data dodania: około 2 miesiące temu', 'Data aktualizacji: 15 dni temu'],
#   [['Powierzchnia', '19 m²'],
#    ['Liczba pokoi', '1'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '3'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1935'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '310 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/kawalerka-inwestycyjna-zabezpiecz-sie-przed-inflac-ID45qdc.html#6f30623213'),
#  ('Warszawa, Wola, ul. Marcina Kasprzaka',
#   '799 000 zł',
#   ['Data dodania: 2 miesiące temu', 'Data aktualizacji: około 21 godzin temu'],
#   [['Powierzchnia', '71,37 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '5'],
#    ['Liczba pięter', '8'],
#    ['Materiał budynku', 'inne'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2019'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/pilnie-do-odbioru-3-pok-ul-kasprzaka-blisko-metra-ID45jPa.html#bdc3382d00'),
#  ('Warszawa, Wilanów, Franciszka Klimczaka',
#   '1 390 000 zł',
#   ['Data dodania: 11 dni temu', 'Data aktualizacji: dzień temu'],
#   [['Powierzchnia', '103 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/bardzo-ladne-3-pokojowe-mieszkanie-na-wilanowe-ID460Ke.html#c660ee25b3'),
#  ('Warszawa, Ursus, Dzieci Warszawy',
#   '346 720 zł',
#   ['Data dodania: 30 dni temu', 'Data aktualizacji: 15 dni temu'],
#   [['Powierzchnia', '35,20 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2022'],
#    ['Stan wykończenia', 'do wykończenia']],
#   'https://www.otodom.pl/oferta/najtansze-dwa-pokoje-komfortowy-uklad-ID45Hu5.html#ef6092fb9c'),
#  ('Warszawa, Białołęka, Żerań',
#   '409 000 zł',
#   ['Data dodania: 28 dni temu', 'Data aktualizacji: 7 dni temu'],
#   [['Powierzchnia', '58,42 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'blok'],
#    ['Piętro', '1'],
#    ['Liczba pięter', '5'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Dostępne od', '2020-10-30']],
#   'https://www.otodom.pl/oferta/zeran-blisko-pkp-i-s8-na-2020r-negocjuj-cene-ID45KbR.html#37e55cf923'),
#  ('Warszawa, Mokotów, Sielce',
#   '390 000 zł',
#   ['Data dodania: 3 dni temu', 'Data aktualizacji: za około 2 godziny'],
#   [['Powierzchnia', '36,60 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'wtórny'],
#    ['Liczba pięter', '4'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'plastikowe'],
#    ['Rok budowy', '1967'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Czynsz', '347 zł']],
#   'https://www.otodom.pl/oferta/2-pok-metro-wierzbno-sgh-sggw-wum-park-lazienki-ID4681S.html#bb40013e62'),
#  ('Warszawa, Śródmieście, Śródmieście Południowe, ul. Koszykowa',
#   '1 049 000 zł',
#   ['Data dodania: 13 dni temu', 'Data aktualizacji: 13 dni temu'],
#   [['Powierzchnia', '86,57 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'kamienica'],
#    ['Piętro', '4'],
#    ['Liczba pięter', '5'],
#    ['Materiał budynku', 'cegła'],
#    ['Okna', 'drewniane'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '1932'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '830 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/koszykowa-do-dowolnej-aranzacji-z-potencjalem-ID45Zjw.html#bb6e6f5d78'),
#  ('Warszawa, Praga-Południe, spalinowa 9',
#   '632 160 zł',
#   ['Data dodania: 4 miesiące temu', 'Data aktualizacji: 9 dni temu'],
#   [['Powierzchnia', '52,68 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '3'],
#    ['Ogrzewanie', 'gazowe'],
#    ['Rok budowy', '2020'],
#    ['Stan wykończenia', 'do wykończenia'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2021-01-31']],
#   'https://www.otodom.pl/oferta/praga-poludnie-rondo-wiatraczna-ul-spalinowa-9-ID44Dcl.html#e29d7c665b'),
#  ('Warszawa, Śródmieście, Złota 44',
#   '4 490 000 zł',
#   ['Data dodania: około 2 lata temu', 'Data aktualizacji: 2 dni temu'],
#   [['Powierzchnia', '99 m²'],
#    ['Liczba pokoi', '2'],
#    ['Rynek', 'pierwotny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '> 10'],
#    ['Liczba pięter', '52'],
#    ['Materiał budynku', 'żelbet'],
#    ['Okna', 'plastikowe'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2017'],
#    ['Stan wykończenia', 'do zamieszkania'],
#    ['Forma własności', 'pełna własność'],
#    ['Dostępne od', '2018-03-19']],
#   'https://www.otodom.pl/oferta/bezposrednio-zlota-44-w-pelni-umeblowany-ID3ALoP.html#550cdef8bb'),
#  ('Warszawa, Mokotów, Sielce',
#   '5 250 000 zł',
#   ['Data dodania: 9 dni temu', 'Data aktualizacji: 6 dni temu'],
#   [['Powierzchnia', '186,70 m²'],
#    ['Liczba pokoi', '3'],
#    ['Rynek', 'wtórny'],
#    ['Rodzaj zabudowy', 'apartamentowiec'],
#    ['Piętro', '2'],
#    ['Liczba pięter', '5'],
#    ['Ogrzewanie', 'miejskie'],
#    ['Rok budowy', '2001'],
#    ['Stan wykończenia', 'do remontu'],
#    ['Czynsz', '3 000 zł'],
#    ['Forma własności', 'pełna własność']],
#   'https://www.otodom.pl/oferta/apartament-w-villi-monaco-z-70m2-tarasem-ID462ZJ.html#2b439c88db'),
#  ...]

# %% [markdown]
# ### Getting all possible parameters of properties

# %%
list_of_results_2 = [data[3] for data in list_of_results]
all_params = set([x[0] for y in list_of_results_2 for x in y])

# %% [markdown]
# ### Creating final dictionary to pass it to pandas dataframe

# %%
final_dict = {}
final_dict["location"] = []
final_dict["total_price"] = []
final_dict["initial_date"] = []
final_dict["update_date"] = []
final_dict["link"] =[]
for param in all_params:
    final_dict[param] = []

# %%
for result in list_of_results:
    
    ## Getting location
    location = result[0]
    
    ## Getting total_price
    total_price = result[1]
    
    ## Getting dates
    initial_date = result[2][0]
    update_date = result[2][1]
    
    ## Getting link
    link = result[4]
    
    ## Saving above to dictionary 
    final_dict["location"].append(location)
    final_dict["total_price"].append(total_price)
    final_dict["initial_date"].append(initial_date)
    final_dict["update_date"].append(update_date)
    final_dict["link"].append(link)
    
    
    ## Getting params
    available_parameters = dict(result[3].copy())
    
    for param in all_params:
        
        if param in available_parameters.keys():
            final_dict[param].append(available_parameters[param])
        
        else:
            final_dict[param].append(None)

# %%
df = pd.DataFrame(final_dict)

# %% [markdown]
# ## Adjusting dataframe

# %% [markdown]
# #### unpacking location

# %%
df_location = df.location.str.split(",", n = 4, expand = True)

# %%
df_location.columns = ["City", "District", "Detailed_location", "Additional_info", "Other"]

# %%
detailed_loc = df_location.apply(lambda x: x["Detailed_location"] if str(x["Additional_info"]) == "None" else x["Additional_info"], axis = 1)

# %%
df_location["Detailed_location_full"] = detailed_loc

# %% [markdown]
# ### total_price

# %%
def extract_price(text):
    
    text = text.replace("zł", "")
    text = text.replace(" ", "")
    text = text.replace(",", ".")
    
    try:
        final_price = float(text)
    except:
        final_price = None
    
    return final_price

# %%
df["total_price"] = df.total_price.apply(lambda text: extract_price(text))

# %% [markdown]
# ### Dealing with dates

# %%
df.loc[df["initial_date"].str.contains("minut|godzin|dzień|dni|mies|rok|lat")]
# Out:
#                                                 location  total_price  \
# 0                Warszawa, Białołęka, Nowodwory, Sprawna     365065.0
# 1                            Warszawa, Bemowo, Apenińska     450000.0
# 2                                     Warszawa, Żoliborz     420000.0
# 3                   Warszawa, Żoliborz, Sady Żoliborskie     530000.0
# 4      Warszawa, Mokotów, Górny Mokotów, al. Aleja Wi...          NaN
# 5                                         Warszawa, Wola     735000.0
# 6             Warszawa, Mokotów, Służewiec, Cybernetyki      630070.0
# 7      Warszawa, Białołęka, Dąbrówka Szlachecka, ul. ...     324000.0
# 8      Warszawa, Targówek, Targówek Mieszkaniowy, Mok...     495000.0
# 9                                      Warszawa, Ursynów     820000.0
# 10     Warszawa, Ursus, Skorosze, ul. Aleksandra Prys...     499000.0
# 11         Warszawa, Wola, Górczewska 181/C.H. Wola Park     550000.0
# 12                    Warszawa, Białołęka, ul. Zdziarska          NaN
# 13          Warszawa, Ochota, Juliana Ursyna Niemcewicza    1000000.0
# 14                                 Warszawa, Śródmieście    1015000.0
# 15                                     Warszawa, Mokotów     649000.0
# 16                        Warszawa, Wawer, ul. Zwoleńska     539500.0
# 17                      Warszawa, Żoliborz, ul. Szamocka     630000.0
# 18                                      Warszawa, Ochota     396500.0
# 19                                    Warszawa, Żoliborz     350000.0
# 20                              Warszawa, Praga-Południe     365000.0
# 21                                       Warszawa, Ursus     359000.0
# 22                      Warszawa, Mokotów, Dolny Mokotów    2900000.0
# 23              Warszawa, Praga-Południe, Jugosłowiańska     979700.0
# 24                                     Warszawa, Wilanów     585300.0
# 25                                 Warszawa, Śródmieście     960500.0
# 26                                     Warszawa, Wilanów    1749000.0
# 27                                   Warszawa, Białołęka     399000.0
# 28                            Warszawa, Bemowo, Widawska    1160000.0
# 29                        Warszawa, Ursynów, Alternatywy    1199000.0
# ...                                                  ...          ...
# 10365                                  Warszawa, Mokotów    1587888.0
# 10366                   Warszawa, Bemowo, ul. Grodkowska          NaN
# 10367                       Warszawa, Mokotów, Warneńska     420000.0
# 10368                                     Warszawa, Wola    1218375.0
# 10369            Warszawa, Bemowo, Batalionów Chłopskich     684000.0
# 10370                 Warszawa, Śródmieście, Nowogrodzka    1982650.0
# 10371                       Warszawa, Wola, ul. Piaskowa     629947.5
# 10372                Warszawa, Żoliborz, ul. Gwiaździsta    1850000.0
# 10373    Warszawa, Włochy, Stare Włochy, Czesława Kłosia     819000.0
# 10374                    Warszawa, Wola, Jana Kazimierza     396000.0
# 10375                         Warszawa, Włochy, Rakowska     381480.0
# 10376                                     Warszawa, Wola     669000.0
# 10377     Warszawa, Białołęka, Grodzisk, Kąty Grodziskie     320000.0
# 10378                       Warszawa, Mokotów, Bokserska     506940.0
# 10379  Warszawa, Ochota, Stara Ochota, ul. Jana Danty...    1950000.0
# 10380      Warszawa, Białołęka, Nowodwory, ul. Dionizosa     334000.0
# 10381                        Warszawa, Wola, ul. Grenady     569000.0
# 10382                                  Warszawa, Mokotów     875000.0
# 10383                                   Warszawa, Ochota    1450000.0
# 10384                      Warszawa, Targówek, Goławicka     525500.0
# 10385                    Warszawa, Ursus, Mariana Keniga     290000.0
# 10386                    Warszawa, Wilanów, ul. Sarmacka    1385000.0
# 10387                   Warszawa, Praga-Północ, Szwedzka     748714.0
# 10388            Warszawa, Mokotów, Stegny, Czarnomorska     469000.0
# 10389    Warszawa, Praga-Południe, Grochów, Ostrobramska     595000.0
# 10390                             Warszawa, Praga-Północ     531219.0
# 10391               Warszawa, Rembertów, ul. Chełmżyńska     267292.0
# 10392               Warszawa, Białołęka, Edwarda Wittiga     395000.0
# 10393    Warszawa, Mokotów, Dolny Mokotów, ul. Faworytki     945000.0
# 10394      Pamiętajcie o Ogrodach, Warszawa, mazowieckie     782030.2
#
#                               initial_date  \
# 0                Data dodania: 14 dni temu
# 1                 Data dodania: 9 dni temu
# 2       Data dodania: około 11 godzin temu
# 3                Data dodania: 16 dni temu
# 4                Data dodania: 15 dni temu
# 5                Data dodania: 14 dni temu
# 6                Data dodania: 13 dni temu
# 7                Data dodania: 15 dni temu
# 8                 Data dodania: 3 dni temu
# 9                Data dodania: 11 dni temu
# 10     Data dodania: około 2 miesiące temu
# 11                Data dodania: dzień temu
# 12            Data dodania: ponad rok temu
# 13               Data dodania: 25 dni temu
# 14                Data dodania: 3 dni temu
# 15           Data dodania: 3 miesiące temu
# 16         Data dodania: ponad 2 lata temu
# 17               Data dodania: 14 dni temu
# 18               Data dodania: 22 dni temu
# 19               Data dodania: 24 dni temu
# 20           Data dodania: 2 miesiące temu
# 21        Data dodania: około miesiąc temu
# 22                Data dodania: 2 dni temu
# 23           Data dodania: 4 miesiące temu
# 24               Data dodania: 18 dni temu
# 25               Data dodania: 10 dni temu
# 26               Data dodania: 14 dni temu
# 27                Data dodania: 4 dni temu
# 28          Data dodania: 10 miesięcy temu
# 29               Data dodania: 10 dni temu
# ...                                    ...
# 10365            Data dodania: 17 dni temu
# 10366            Data dodania: 24 dni temu
# 10367            Data dodania: 14 dni temu
# 10368  Data dodania: około 2 miesiące temu
# 10369             Data dodania: 4 dni temu
# 10370            Data dodania: 28 dni temu
# 10371        Data dodania: 4 miesiące temu
# 10372            Data dodania: 10 dni temu
# 10373        Data dodania: 6 miesięcy temu
# 10374            Data dodania: 28 dni temu
# 10375            Data dodania: 25 dni temu
# 10376            Data dodania: 16 dni temu
# 10377     Data dodania: około miesiąc temu
# 10378            Data dodania: 22 dni temu
# 10379        Data dodania: 2 miesiące temu
# 10380            Data dodania: 18 dni temu
# 10381      Data dodania: ponad 2 lata temu
# 10382             Data dodania: 2 dni temu
# 10383             Data dodania: 4 dni temu
# 10384     Data dodania: około miesiąc temu
# 10385             Data dodania: 9 dni temu
# 10386            Data dodania: 15 dni temu
# 10387            Data dodania: 16 dni temu
# 10388             Data dodania: 3 dni temu
# 10389            Data dodania: 24 dni temu
# 10390        Data dodania: 3 miesiące temu
# 10391             Data dodania: 4 dni temu
# 10392     Data dodania: około miesiąc temu
# 10393            Data dodania: 16 dni temu
# 10394            Data dodania: 14 dni temu
#
#                                    update_date  \
# 0                Data aktualizacji: 6 dni temu
# 1                Data aktualizacji: 7 dni temu
# 2      Data aktualizacji: około 11 godzin temu
# 3      Data aktualizacji: około 20 godzin temu
# 4               Data aktualizacji: 15 dni temu
# 5                Data aktualizacji: 4 dni temu
# 6                Data aktualizacji: 5 dni temu
# 7               Data aktualizacji: 13 dni temu
# 8                Data aktualizacji: dzień temu
# 9               Data aktualizacji: 10 dni temu
# 10               Data aktualizacji: 9 dni temu
# 11     Data aktualizacji: około 18 godzin temu
# 12               Data aktualizacji: 5 dni temu
# 13              Data aktualizacji: 25 dni temu
# 14               Data aktualizacji: dzień temu
# 15               Data aktualizacji: 3 dni temu
# 16               Data aktualizacji: 9 dni temu
# 17              Data aktualizacji: 11 dni temu
# 18      Data aktualizacji: około 8 godzin temu
# 19               Data aktualizacji: 8 dni temu
# 20               Data aktualizacji: 3 dni temu
# 21               Data aktualizacji: 6 dni temu
# 22               Data aktualizacji: 2 dni temu
# 23     Data aktualizacji: około 11 godzin temu
# 24               Data aktualizacji: 3 dni temu
# 25              Data aktualizacji: 10 dni temu
# 26               Data aktualizacji: 9 dni temu
# 27               Data aktualizacji: 4 dni temu
# 28              Data aktualizacji: 11 dni temu
# 29               Data aktualizacji: 9 dni temu
# ...                                        ...
# 10365            Data aktualizacji: 3 dni temu
# 10366           Data aktualizacji: 21 dni temu
# 10367           Data aktualizacji: 14 dni temu
# 10368            Data aktualizacji: 9 dni temu
# 10369            Data aktualizacji: 4 dni temu
# 10370           Data aktualizacji: za 20 minut
# 10371            Data aktualizacji: 9 dni temu
# 10372            Data aktualizacji: 9 dni temu
# 10373   Data aktualizacji: około 6 godzin temu
# 10374           Data aktualizacji: 14 dni temu
# 10375           Data aktualizacji: 13 dni temu
# 10376           Data aktualizacji: 16 dni temu
# 10377            Data aktualizacji: 3 dni temu
# 10378            Data aktualizacji: 8 dni temu
# 10379            Data aktualizacji: 8 dni temu
# 10380           Data aktualizacji: 18 dni temu
# 10381            Data aktualizacji: dzień temu
# 10382            Data aktualizacji: 2 dni temu
# 10383            Data aktualizacji: 3 dni temu
# 10384            Data aktualizacji: dzień temu
# 10385            Data aktualizacji: 9 dni temu
# 10386   Data aktualizacji: około 6 godzin temu
# 10387            Data aktualizacji: 3 dni temu
# 10388            Data aktualizacji: 3 dni temu
# 10389           Data aktualizacji: 14 dni temu
# 10390            Data aktualizacji: 8 dni temu
# 10391            Data aktualizacji: 4 dni temu
# 10392   Data aktualizacji: około 5 godzin temu
# 10393         Data aktualizacji: 14 minut temu
# 10394            Data aktualizacji: 7 dni temu
#
#                                                     link    Czynsz  \
# 0      https://www.otodom.pl/oferta/harmonogram-20-80...      None
# 1      https://www.otodom.pl/oferta/bemowo-po-general...      None
# 2      https://www.otodom.pl/oferta/zoliborz-34m2-2-p...      None
# 3      https://www.otodom.pl/oferta/mieszkanie-2-poko...      None
# 4      https://www.otodom.pl/oferta/nowe-mieszkanie-2...      None
# 5      https://www.otodom.pl/oferta/3-pokoje-przy-for...    530 zł
# 6      https://www.otodom.pl/oferta/mieszkanie-trzypo...      None
# 7      https://www.otodom.pl/oferta/ciche-i-przytulne...    500 zł
# 8      https://www.otodom.pl/oferta/metro-trocka-3-po...    690 zł
# 9      https://www.otodom.pl/oferta/mieszkanie-76-5-m...    640 zł
# 10     https://www.otodom.pl/oferta/sprzedam-mieszkan...    385 zł
# 11     https://www.otodom.pl/oferta/c-h-wola-park-ul-...      None
# 12     https://www.otodom.pl/oferta/mieszkanie-f2-m10...      None
# 13     https://www.otodom.pl/oferta/jasne-4-pokoje-10...      None
# 14     https://www.otodom.pl/oferta/metro-kamienica-g...      None
# 15     https://www.otodom.pl/oferta/pole-mokotowskiek...      None
# 16     https://www.otodom.pl/oferta/mieszkanie-82m2-d...      None
# 17     https://www.otodom.pl/oferta/warszawa-zoliborz...    549 zł
# 18     https://www.otodom.pl/oferta/komfortowa-kawale...    280 zł
# 19     https://www.otodom.pl/oferta/kawalerka-w-dosko...    285 zł
# 20     https://www.otodom.pl/oferta/2-pokoje-z-garder...    400 zł
# 21     https://www.otodom.pl/oferta/2-pokoje-na-ursus...      None
# 22     https://www.otodom.pl/oferta/apartament-165m2-...  1 500 zł
# 23     https://www.otodom.pl/oferta/z-ogrodkiem-do-za...      None
# 24     https://www.otodom.pl/oferta/prestizowe-osiedl...      None
# 25     https://www.otodom.pl/oferta/1-pokojowe-w-atra...    350 zł
# 26     https://www.otodom.pl/oferta/penthouse-na-osta...      None
# 27     https://www.otodom.pl/oferta/mieszkanie-53-m-w...    600 zł
# 28     https://www.otodom.pl/oferta/komfortowe-mieszk...  1 100 zł
# 29     https://www.otodom.pl/oferta/klimatyczne-miesz...    940 zł
# ...                                                  ...       ...
# 10365  https://www.otodom.pl/oferta/mieszkanie-warsza...      None
# 10366  https://www.otodom.pl/oferta/esteio-mieszkanie...      None
# 10367  https://www.otodom.pl/oferta/3-pokoje-mokotow-...      None
# 10368  https://www.otodom.pl/oferta/apartament-4-pok-...      None
# 10369  https://www.otodom.pl/oferta/odbior-maj20-l-4p...      None
# 10370  https://www.otodom.pl/oferta/wyjatkowe-mieszka...      None
# 10371  https://www.otodom.pl/oferta/mieszkanie-piasko...     10 zł
# 10372  https://www.otodom.pl/oferta/mieszkanie-134-40...      None
# 10373  https://www.otodom.pl/oferta/mieszkanie-z-komi...    300 zł
# 10374  https://www.otodom.pl/oferta/parter-z-ogrodkie...      None
# 10375  https://www.otodom.pl/oferta/kompaktowe-2-poko...      None
# 10376  https://www.otodom.pl/oferta/mieszkanie-na-spr...    440 zł
# 10377  https://www.otodom.pl/oferta/piekne-mieszkania...      None
# 10378  https://www.otodom.pl/oferta/7-min-do-galerii-...      None
# 10379  https://www.otodom.pl/oferta/kamienica-stara-o...    350 zł
# 10380  https://www.otodom.pl/oferta/swiezo-urzadzone-...    380 zł
# 10381  https://www.otodom.pl/oferta/warszawa-wola-ul-...    580 zł
# 10382  https://www.otodom.pl/oferta/nowy-wykonczony-a...      None
# 10383  https://www.otodom.pl/oferta/mieszkanie-94-40-...      None
# 10384  https://www.otodom.pl/oferta/3-pokoje-panorama...      None
# 10385  https://www.otodom.pl/oferta/rozkladowa-kawale...      None
# 10386  https://www.otodom.pl/oferta/apartament-z-ogro...  1 000 zł
# 10387  https://www.otodom.pl/oferta/bez-podatku-pcc-o...    500 zł
# 10388  https://www.otodom.pl/oferta/bezposrednioblisk...      None
# 10389  https://www.otodom.pl/oferta/mieszkanie-w-wars...      None
# 10390  https://www.otodom.pl/oferta/atelier-praga-2-p...      None
# 10391  https://www.otodom.pl/oferta/nowe-2-pokoje-35-...      None
# 10392  https://www.otodom.pl/oferta/trzypokojowe-mies...      None
# 10393  https://www.otodom.pl/oferta/mieszkanie-2-poko...      None
# 10394  https://www.otodom.pl/oferta/apartament-na-sro...      None
#
#                  Forma własności Materiał budynku  Piętro        Okna  \
# 0                           None             None       1        None
# 1                 pełna własność             None       2        None
# 2                           None             None    > 10        None
# 3                           None             inne       3        None
# 4                 pełna własność           żelbet       5  plastikowe
# 5                 pełna własność             None       6  plastikowe
# 6                           None             inne       4        None
# 7                 pełna własność            cegła  parter  plastikowe
# 8                 pełna własność     wielka płyta       4        None
# 9      spółdzielcze własnościowe     wielka płyta       9  plastikowe
# 10                pełna własność             None       1  plastikowe
# 11                pełna własność            cegła       3        None
# 12                          None             None       1        None
# 13                pełna własność             None       6   drewniane
# 14                          None            cegła       2        None
# 15                          None             None  parter        None
# 16                pełna własność           pustak    None  plastikowe
# 17                pełna własność             None       1   drewniane
# 18                pełna własność             None       4   drewniane
# 19                pełna własność     wielka płyta       2  plastikowe
# 20     spółdzielcze własnościowe             inne       1  plastikowe
# 21                pełna własność             inne       2  plastikowe
# 22                pełna własność           pustak       7  plastikowe
# 23         spółdzielcze wł. z KW             None       1        None
# 24                          None             None       4        None
# 25         spółdzielcze wł. z KW             None    > 10  plastikowe
# 26                pełna własność             inne       5  plastikowe
# 27                pełna własność             None       3  plastikowe
# 28     spółdzielcze własnościowe            cegła       3        None
# 29                pełna własność            cegła  parter        None
# ...                          ...              ...     ...         ...
# 10365                       None             None       3        None
# 10366             pełna własność             None  parter        None
# 10367  spółdzielcze własnościowe     wielka płyta       4        None
# 10368                       None             None    > 10        None
# 10369             pełna własność             inne       1        None
# 10370                       None            cegła       4        None
# 10371             pełna własność             None       5   drewniane
# 10372                       None            cegła       5  plastikowe
# 10373             pełna własność             None       1        None
# 10374                       None            cegła  parter  plastikowe
# 10375                       None             None       4        None
# 10376             pełna własność            cegła       1        None
# 10377                       None             inne       2        None
# 10378                       None             None  parter        None
# 10379             pełna własność            cegła       1   drewniane
# 10380             pełna własność            cegła  parter  plastikowe
# 10381             pełna własność           żelbet       3  plastikowe
# 10382             pełna własność             inne       7  plastikowe
# 10383                       None            cegła       1        None
# 10384  spółdzielcze własnościowe     wielka płyta      10        None
# 10385             pełna własność             None       4        None
# 10386             pełna własność             None  parter   drewniane
# 10387             pełna własność             None       4  plastikowe
# 10388                       None             None       5        None
# 10389             pełna własność            cegła       3        None
# 10390             pełna własność            cegła       5        None
# 10391             pełna własność          silikat  parter  plastikowe
# 10392      spółdzielcze wł. z KW             None       4        None
# 10393             pełna własność             None       4   drewniane
# 10394                       None             None       7        None
#
#        Rodzaj zabudowy Stan wykończenia Liczba pięter      Rynek Powierzchnia  \
# 0                 None             None             5  pierwotny     50,34 m²
# 1                 blok             None             3     wtórny     46,70 m²
# 2                 None             None            17     wtórny        34 m²
# 3                 blok  do zamieszkania             3     wtórny     46,60 m²
# 4      apartamentowiec   do wykończenia             6  pierwotny     53,27 m²
# 5                 blok   do wykończenia             7  pierwotny        59 m²
# 6                 blok   do wykończenia             7     wtórny     60,22 m²
# 7                 blok  do zamieszkania             4     wtórny        39 m²
# 8                 blok       do remontu            10     wtórny        64 m²
# 9                 blok   do wykończenia            12     wtórny     76,50 m²
# 10                blok  do zamieszkania             4     wtórny     44,48 m²
# 11     apartamentowiec             None             5     wtórny        50 m²
# 12                blok             None             4  pierwotny     81,56 m²
# 13                blok  do zamieszkania            14     wtórny        92 m²
# 14           kamienica             None             4     wtórny        60 m²
# 15                None             None             4     wtórny     62,46 m²
# 16         szeregowiec   do wykończenia             1  pierwotny     82,49 m²
# 17     apartamentowiec  do zamieszkania             6     wtórny        44 m²
# 18                blok  do zamieszkania             6     wtórny     26,30 m²
# 19                blok  do zamieszkania            10     wtórny     28,50 m²
# 20                blok       do remontu            10     wtórny        37 m²
# 21                blok             None             7     wtórny        44 m²
# 22     apartamentowiec  do zamieszkania             9     wtórny       165 m²
# 23                None  do zamieszkania             6     wtórny        87 m²
# 24                None             None             4  pierwotny     66,34 m²
# 25                blok  do zamieszkania            23     wtórny        41 m²
# 26     apartamentowiec             None             5     wtórny       133 m²
# 27                blok  do zamieszkania             4     wtórny        53 m²
# 28                blok       do remontu             4     wtórny    117,51 m²
# 29     apartamentowiec  do zamieszkania             7     wtórny       110 m²
# ...                ...              ...           ...        ...          ...
# 10365             None             None             4     wtórny        85 m²
# 10366             blok   do wykończenia             8  pierwotny     62,62 m²
# 10367             blok       do remontu             4     wtórny     53,30 m²
# 10368  apartamentowiec             None            27  pierwotny     90,25 m²
# 10369             blok   do wykończenia             6     wtórny     85,57 m²
# 10370        kamienica   do wykończenia             5     wtórny    104,35 m²
# 10371             blok       do remontu             6     wtórny     52,50 m²
# 10372  apartamentowiec  do zamieszkania             5     wtórny    134,40 m²
# 10373  apartamentowiec  do zamieszkania             2     wtórny     83,70 m²
# 10374  apartamentowiec   do wykończenia             6     wtórny        33 m²
# 10375  apartamentowiec   do wykończenia             8  pierwotny     31,45 m²
# 10376             blok             None          None     wtórny     56,20 m²
# 10377             blok   do wykończenia             2     wtórny     40,74 m²
# 10378             None   do wykończenia            10  pierwotny     50,42 m²
# 10379        kamienica  do zamieszkania             2     wtórny        80 m²
# 10380  apartamentowiec  do zamieszkania             8     wtórny     32,82 m²
# 10381             blok  do zamieszkania             3     wtórny     46,20 m²
# 10382             blok  do zamieszkania             7     wtórny        73 m²
# 10383             None             None             4     wtórny     94,40 m²
# 10384             blok             None            12     wtórny        64 m²
# 10385             blok  do zamieszkania             4     wtórny        30 m²
# 10386  apartamentowiec  do zamieszkania             4     wtórny     99,52 m²
# 10387             blok   do wykończenia             5  pierwotny     61,37 m²
# 10388  apartamentowiec   do wykończenia             6  pierwotny     38,50 m²
# 10389             blok  do zamieszkania             4     wtórny        73 m²
# 10390  apartamentowiec   do wykończenia             7  pierwotny     39,93 m²
# 10391  apartamentowiec   do wykończenia             5  pierwotny     35,17 m²
# 10392             None             None            10     wtórny        62 m²
# 10393             blok             None             6     wtórny        63 m²
# 10394             None             None             8  pierwotny     62,57 m²
#
#       Dostępne od Liczba pokoi Rok budowy Ogrzewanie
# 0            None            2       2020       None
# 1            None            3       1989   miejskie
# 2            None            2       1967       None
# 3            None            2       1964   miejskie
# 4            None            2       2021   miejskie
# 5            None            3       2019       None
# 6            None            3       2020   miejskie
# 7            None            2       1999   miejskie
# 8            None            3       1975   miejskie
# 9            None            4       1985   miejskie
# 10           None            2       2017   miejskie
# 11           None            3       2008   miejskie
# 12           None            4       2020       None
# 13           None            4       2003   miejskie
# 14           None            2       1937       None
# 15           None            3       1937       None
# 16     2020-12-30            4       2020     gazowe
# 17           None            2       2016   miejskie
# 18           None            1       2011       None
# 19           None            1       1976       None
# 20     2020-05-24            2       1982   miejskie
# 21           None            2       2021   miejskie
# 22           None            3       2004   miejskie
# 23     2020-02-01            3       2011       None
# 24           None            4       2021       None
# 25     2020-05-25            1       None   miejskie
# 26           None            5       2019   miejskie
# 27           None            2       2001       None
# 28           None            6       1998   miejskie
# 29           None            4       2006   miejskie
# ...           ...          ...        ...        ...
# 10365  2020-02-01            3       2014       None
# 10366        None            3       2021       None
# 10367  2020-05-01            3       1973   miejskie
# 10368        None            4       2021   miejskie
# 10369        None            4       2020   miejskie
# 10370        None            4       None   miejskie
# 10371  2020-07-31            2       2006   miejskie
# 10372  2019-01-01            4       2000   miejskie
# 10373        None            3       2008       None
# 10374        None            2       2020   miejskie
# 10375        None            2       2020       None
# 10376        None            2       2013       None
# 10377        None            2       None   miejskie
# 10378        None            3       2021       None
# 10379        None            3       None     gazowe
# 10380  2020-05-18            2       2020   miejskie
# 10381  2020-06-01            3       1980   miejskie
# 10382        None            4       2019   miejskie
# 10383        None            4       2019       None
# 10384        None            3       1977       None
# 10385  2020-05-27            1       1977       None
# 10386        None            4       2017   miejskie
# 10387        None            2       2020       None
# 10388        None            2       2020       None
# 10389        None            4       1990   miejskie
# 10390        None            2       2020       None
# 10391  2021-05-01            2       2021   miejskie
# 10392        None            3       1985       None
# 10393        None            2       2017   miejskie
# 10394        None            3       None       None
#
# [10395 rows x 19 columns]

# %% [markdown]
# #### Możliwe warunki
# Czas liczony w dniach
#
# * Minut i godzin -> Przekonwertowane na less than a day
# * Dzień -> 1
# * Dni (liczba - d) -> 1 * d
# * Miesięcy (liczba - m) -> m * 30
# * rok/lat (liczba - y) -> y * 365

# %%
import re

# %%
def date_extractor(x):
    
    
    x = x.replace("około ", "")
    x = x.replace("prawie ", "")
    x = x.replace("ponad ", "")
    
    if len(re.findall("minut|godzin", x)) > 0:
        return "Less than a day"
    
    elif "dzień" in x:
        return 1
    
    elif "dni " in x:
        x = x.replace("Data dodania: ", "")
        x = x.replace(" dni temu", "")
        
        return int(x)
    
    elif "miesiąc " in x:
        
        return 30
    
    elif any(m in x for m in ["miesiące", "miesięcy"]) == True:
        
        
        x = x.replace("Data dodania: ", "")
        x = x.replace(" miesiące temu", "")
        x = x.replace(" miesięcy temu", "")
        x = 30 * int(x)
        return x
    
    elif "rok" in x:
        return 365
    
    
     
    
    else:
        
#         x = x.replace("około ", "")
#         x = x.replace("ponad ", "")
        x = x.replace("Data dodania: ", "")
        x = x.replace(" lata temu", "")
        x = x.replace(" lat temu", "")
        
        x = 365 * int(x)
        
        return x

# %%
days_from_initial_announcement = df.initial_date.apply(lambda x: date_extractor(x))

# %% [markdown]
# ### Dealing with powierzchnia

# %%
df["Powierzchnia"] = df["Powierzchnia"].apply(lambda x: float(x.split(" ")[0].replace(",", ".")))

# %% [markdown]
# ### Dealing with czynsz

# %%
df["Czynsz"] = df["Czynsz"].apply(lambda x: float(x.replace(" zł", "").replace(" ", "").replace(",", ".")) if str(x) != 'None' else None)

# %% [markdown]
# ### Final df

# %%
df_final = df_location.iloc[:,[1,5,4]].copy()

# %%
df_final["Total_price"] = df.loc[:,"total_price"]

# %%
df_final["Dates_from_initial_announcement"] = days_from_initial_announcement

# %%
df_final = pd.concat([df_final, df.iloc[:,5:]], axis = 1)

# %%
df_final = df_final.loc[df_final["Other"].isna() == True]

# %%
df_final = df_final.loc[df_final["Total_price"].isna() == False]

# %%
df_final.drop(columns = ["Other"], inplace = True)

# %%
df_final.reset_index(drop = True, inplace = True)

# %% [markdown]
# ## Getting distance from city center (Pałac kultury i nauki)

# %% [markdown]
# #### First let's get coordinates of each location

# %%
headers = {
    "User-Agent": "MFHUSTLA420",
    "email": "grego23@onet.eu"
}
def get_coordinates(suburb, street, headers = headers):

    if street is not None:
        request = "https://nominatim.openstreetmap.org/search?suburb={}&street={}&city=Warsaw&country=pl&format=json&polygon=1&addressdetails=1&limit=1".format(suburb, street)
        
    else:
        request = "https://nominatim.openstreetmap.org/search?suburb={}&city=Warsaw&country=pl&format=json&polygon=1&addressdetails=1&limit=1".format(suburb)
    
    data = requests.get(request, headers = headers)
    data = data.json()
    
    data = data[0]
    
    lat, lon = (data["lat"], data["lon"])
    time.sleep(1.5)
    
    return((lat, lon))

# %%
list_of_coordinates = []
for i in range(0, len(df_final)):
    
    if i % 50 == 0:
        print(i)
    
    try:
        suburb = df_final.loc[i, "District"]
        street = df_final.loc[i, "Detailed_location_full"]
        lat, lon = get_coordinates(suburb, street)
        
    except:
        lat = None
        lon = None
    
    output = (i, lat, lon)
    
    list_of_coordinates.append(output)
    
    with open("coordinates.txt", "a", encoding = 'utf-8') as file:
        file.write(str(output))
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050

# %%
df_final = pd.concat([df_final, pd.DataFrame(list_of_coordinates, columns = ["ID", "Lat", "Lon"]).iloc[:,1:]], axis = 1)

# %%
df_final = df_final.loc[df_final["Lat"].isna() == False]
df_final.reset_index(inplace = True, drop = True)

# %%
pkin = get_coordinates("Śródmieście", "plac Defilad 1")

# %% [markdown]
# ### Now let's get distance

# %%
def get_distance(lat, lon, headers = headers):
    
    ## We need to pass longitute and latituted of the location, second coordinates are constant for PKiN
    ## '52.2317641', '21.005799675616117'
    
    ## Generally we check the driving time
    request = 'http://router.project-osrm.org/route/v1/driving/{},{};21.005799675616117,52.2317641'.format(lon, lat)
    data = requests.get(request)
    data = data.json()
    
    ## Distance is in meters so we convert it to kms
    distance = data['routes'][0]['legs'][0]['distance']/1000
    
     ## Duration is in seconds, so convert to minutes
    time = data['routes'][0]['legs'][0]['duration']/60
    
    return ((distance, time))

# %%
test = get_distance(lat_test, lon_test)

# %%
import time as tm

# %%
list_of_distances = []
control = []
for i in range(0, len(df_final)):
    
    if i % 50 == 0:
        print(i)
    
    if df_final.loc[i, "Detailed_location_full"] is not None:
    
        lat = df_final.loc[i, "Lat"]
        lon = df_final.loc[i, "Lon"]

        try:
            distance, time = get_distance(lat, lon)
            control = []
        except:
            distance, time = (None, None)
            control.append("err")
    
    else:
        distance, time = (None, None)
        
    
    output = (i, distance, time)
    
    list_of_distances.append(output)
    
    with open("distances.txt", "a", encoding = 'utf-8') as file:
        file.write(str(output))
        
    tm.sleep(1)
    
    if len(control) == 20:
        print("too many empties")
        break
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750

# %%
df_final = pd.concat([df_final, pd.DataFrame(list_of_distances, columns = ["ID", "Distance_to_PKIN_in_km", "Time_to_PKIN_in_minutes"]).iloc[:,1:]], axis =1)

# %% [markdown]
# ### Kiedy są same dzielnice podane, to wtedy nie ma odległości i czasu. Więc zinputuję średnim czasem i odległością

# %%
df_final
# Out:
#              District       Detailed_location_full  Total_price  \
# 0           Białołęka                      Sprawna     365065.0
# 1              Bemowo                    Apenińska     450000.0
# 2            Żoliborz                         None     420000.0
# 3            Żoliborz             Sady Żoliborskie     530000.0
# 4                Wola                         None     735000.0
# 5             Mokotów                 Cybernetyki      630070.0
# 6           Białołęka                ul. Przylesie     324000.0
# 7            Targówek                      Mokra 4     495000.0
# 8             Ursynów                         None     820000.0
# 9               Ursus      ul. Aleksandra Prystora     499000.0
# 10             Ochota   Juliana Ursyna Niemcewicza    1000000.0
# 11        Śródmieście                         None    1015000.0
# 12            Mokotów                         None     649000.0
# 13              Wawer                ul. Zwoleńska     539500.0
# 14           Żoliborz                 ul. Szamocka     630000.0
# 15             Ochota                         None     396500.0
# 16           Żoliborz                         None     350000.0
# 17     Praga-Południe                         None     365000.0
# 18              Ursus                         None     359000.0
# 19     Praga-Południe               Jugosłowiańska     979700.0
# 20            Wilanów                         None     585300.0
# 21        Śródmieście                         None     960500.0
# 22            Wilanów                         None    1749000.0
# 23          Białołęka                         None     399000.0
# 24             Bemowo                     Widawska    1160000.0
# 25            Ursynów                  Alternatywy    1199000.0
# 26            Mokotów                         None     592895.0
# 27          Białołęka                      Odkryta     265000.0
# 28            Mokotów                Czerniakowska     469000.0
# 29               Wola                     Ogrodowa     939000.0
# ...               ...                          ...          ...
# 9756   Praga-Południe                         None     777950.0
# 9757          Mokotów                         None    1587888.0
# 9758          Mokotów                    Warneńska     420000.0
# 9759             Wola                         None    1218375.0
# 9760           Bemowo        Batalionów Chłopskich     684000.0
# 9761      Śródmieście                  Nowogrodzka    1982650.0
# 9762             Wola                 ul. Piaskowa     629947.5
# 9763         Żoliborz              ul. Gwiaździsta    1850000.0
# 9764           Włochy              Czesława Kłosia     819000.0
# 9765             Wola              Jana Kazimierza     396000.0
# 9766           Włochy                     Rakowska     381480.0
# 9767             Wola                         None     669000.0
# 9768        Białołęka              Kąty Grodziskie     320000.0
# 9769          Mokotów                    Bokserska     506940.0
# 9770           Ochota           ul. Jana Dantyszka    1950000.0
# 9771        Białołęka                ul. Dionizosa     334000.0
# 9772             Wola                  ul. Grenady     569000.0
# 9773          Mokotów                         None     875000.0
# 9774           Ochota                         None    1450000.0
# 9775         Targówek                    Goławicka     525500.0
# 9776            Ursus               Mariana Keniga     290000.0
# 9777          Wilanów                 ul. Sarmacka    1385000.0
# 9778     Praga-Północ                     Szwedzka     748714.0
# 9779          Mokotów                 Czarnomorska     469000.0
# 9780   Praga-Południe                 Ostrobramska     595000.0
# 9781     Praga-Północ                         None     531219.0
# 9782        Rembertów              ul. Chełmżyńska     267292.0
# 9783        Białołęka              Edwarda Wittiga     395000.0
# 9784          Mokotów                ul. Faworytki     945000.0
# 9785         Warszawa                  mazowieckie     782030.2
#
#      Dates_from_initial_announcement  Czynsz            Forma własności  \
# 0                                 14     NaN                       None
# 1                                  9     NaN             pełna własność
# 2                    Less than a day     NaN                       None
# 3                                 16     NaN                       None
# 4                                 14   530.0             pełna własność
# 5                                 13     NaN                       None
# 6                                 15   500.0             pełna własność
# 7                                  3   690.0             pełna własność
# 8                                 11   640.0  spółdzielcze własnościowe
# 9                                 60   385.0             pełna własność
# 10                                25     NaN             pełna własność
# 11                                 3     NaN                       None
# 12                                90     NaN                       None
# 13                               730     NaN             pełna własność
# 14                                14   549.0             pełna własność
# 15                                22   280.0             pełna własność
# 16                                24   285.0             pełna własność
# 17                                60   400.0  spółdzielcze własnościowe
# 18                                30     NaN             pełna własność
# 19                               120     NaN      spółdzielcze wł. z KW
# 20                                18     NaN                       None
# 21                                10   350.0      spółdzielcze wł. z KW
# 22                                14     NaN             pełna własność
# 23                                 4   600.0             pełna własność
# 24                               300  1100.0  spółdzielcze własnościowe
# 25                                10   940.0             pełna własność
# 26                                 9     NaN                       None
# 27                                30   300.0             pełna własność
# 28                                15   400.0             pełna własność
# 29                                21     NaN                       None
# ...                              ...     ...                        ...
# 9756                               8   620.0  spółdzielcze własnościowe
# 9757                              17     NaN                       None
# 9758                              14     NaN  spółdzielcze własnościowe
# 9759                              60     NaN                       None
# 9760                               4     NaN             pełna własność
# 9761                              28     NaN                       None
# 9762                             120    10.0             pełna własność
# 9763                              10     NaN                       None
# 9764                             180   300.0             pełna własność
# 9765                              28     NaN                       None
# 9766                              25     NaN                       None
# 9767                              16   440.0             pełna własność
# 9768                              30     NaN                       None
# 9769                              22     NaN                       None
# 9770                              60   350.0             pełna własność
# 9771                              18   380.0             pełna własność
# 9772                             730   580.0             pełna własność
# 9773                               2     NaN             pełna własność
# 9774                               4     NaN                       None
# 9775                              30     NaN  spółdzielcze własnościowe
# 9776                               9     NaN             pełna własność
# 9777                              15  1000.0             pełna własność
# 9778                              16   500.0             pełna własność
# 9779                               3     NaN                       None
# 9780                              24     NaN             pełna własność
# 9781                              90     NaN             pełna własność
# 9782                               4     NaN             pełna własność
# 9783                              30     NaN      spółdzielcze wł. z KW
# 9784                              16     NaN             pełna własność
# 9785                              14     NaN                       None
#
#      Materiał budynku  Piętro        Okna  Rodzaj zabudowy  ...      Rynek  \
# 0                None       1        None             None  ...  pierwotny
# 1                None       2        None             blok  ...     wtórny
# 2                None    > 10        None             None  ...     wtórny
# 3                inne       3        None             blok  ...     wtórny
# 4                None       6  plastikowe             blok  ...  pierwotny
# 5                inne       4        None             blok  ...     wtórny
# 6               cegła  parter  plastikowe             blok  ...     wtórny
# 7        wielka płyta       4        None             blok  ...     wtórny
# 8        wielka płyta       9  plastikowe             blok  ...     wtórny
# 9                None       1  plastikowe             blok  ...     wtórny
# 10               None       6   drewniane             blok  ...     wtórny
# 11              cegła       2        None        kamienica  ...     wtórny
# 12               None  parter        None             None  ...     wtórny
# 13             pustak    None  plastikowe      szeregowiec  ...  pierwotny
# 14               None       1   drewniane  apartamentowiec  ...     wtórny
# 15               None       4   drewniane             blok  ...     wtórny
# 16       wielka płyta       2  plastikowe             blok  ...     wtórny
# 17               inne       1  plastikowe             blok  ...     wtórny
# 18               inne       2  plastikowe             blok  ...     wtórny
# 19               None       1        None             None  ...     wtórny
# 20               None       4        None             None  ...  pierwotny
# 21               None    > 10  plastikowe             blok  ...     wtórny
# 22               inne       5  plastikowe  apartamentowiec  ...     wtórny
# 23               None       3  plastikowe             blok  ...     wtórny
# 24              cegła       3        None             blok  ...     wtórny
# 25              cegła  parter        None  apartamentowiec  ...     wtórny
# 26               None       2        None             None  ...  pierwotny
# 27              cegła  parter   drewniane             blok  ...     wtórny
# 28              cegła       5  plastikowe             None  ...     wtórny
# 29               None       2  plastikowe        kamienica  ...     wtórny
# ...               ...     ...         ...              ...  ...        ...
# 9756             None    > 10        None             blok  ...     wtórny
# 9757             None       3        None             None  ...     wtórny
# 9758     wielka płyta       4        None             blok  ...     wtórny
# 9759             None    > 10        None  apartamentowiec  ...  pierwotny
# 9760             inne       1        None             blok  ...     wtórny
# 9761            cegła       4        None        kamienica  ...     wtórny
# 9762             None       5   drewniane             blok  ...     wtórny
# 9763            cegła       5  plastikowe  apartamentowiec  ...     wtórny
# 9764             None       1        None  apartamentowiec  ...     wtórny
# 9765            cegła  parter  plastikowe  apartamentowiec  ...     wtórny
# 9766             None       4        None  apartamentowiec  ...  pierwotny
# 9767            cegła       1        None             blok  ...     wtórny
# 9768             inne       2        None             blok  ...     wtórny
# 9769             None  parter        None             None  ...  pierwotny
# 9770            cegła       1   drewniane        kamienica  ...     wtórny
# 9771            cegła  parter  plastikowe  apartamentowiec  ...     wtórny
# 9772           żelbet       3  plastikowe             blok  ...     wtórny
# 9773             inne       7  plastikowe             blok  ...     wtórny
# 9774            cegła       1        None             None  ...     wtórny
# 9775     wielka płyta      10        None             blok  ...     wtórny
# 9776             None       4        None             blok  ...     wtórny
# 9777             None  parter   drewniane  apartamentowiec  ...     wtórny
# 9778             None       4  plastikowe             blok  ...  pierwotny
# 9779             None       5        None  apartamentowiec  ...  pierwotny
# 9780            cegła       3        None             blok  ...     wtórny
# 9781            cegła       5        None  apartamentowiec  ...  pierwotny
# 9782          silikat  parter  plastikowe  apartamentowiec  ...  pierwotny
# 9783             None       4        None             None  ...     wtórny
# 9784             None       4   drewniane             blok  ...     wtórny
# 9785             None       7        None             None  ...  pierwotny
#
#      Powierzchnia Dostępne od  Liczba pokoi Rok budowy Ogrzewanie  \
# 0           50.34        None             2       2020       None
# 1           46.70        None             3       1989   miejskie
# 2           34.00        None             2       1967       None
# 3           46.60        None             2       1964   miejskie
# 4           59.00        None             3       2019       None
# 5           60.22        None             3       2020   miejskie
# 6           39.00        None             2       1999   miejskie
# 7           64.00        None             3       1975   miejskie
# 8           76.50        None             4       1985   miejskie
# 9           44.48        None             2       2017   miejskie
# 10          92.00        None             4       2003   miejskie
# 11          60.00        None             2       1937       None
# 12          62.46        None             3       1937       None
# 13          82.49  2020-12-30             4       2020     gazowe
# 14          44.00        None             2       2016   miejskie
# 15          26.30        None             1       2011       None
# 16          28.50        None             1       1976       None
# 17          37.00  2020-05-24             2       1982   miejskie
# 18          44.00        None             2       2021   miejskie
# 19          87.00  2020-02-01             3       2011       None
# 20          66.34        None             4       2021       None
# 21          41.00  2020-05-25             1       None   miejskie
# 22         133.00        None             5       2019   miejskie
# 23          53.00        None             2       2001       None
# 24         117.51        None             6       1998   miejskie
# 25         110.00        None             4       2006   miejskie
# 26          58.62        None             3       2020       None
# 27          33.00        None             1       1999       None
# 28          37.00        None             2       1960   miejskie
# 29          67.00        None             4       1954       None
# ...           ...         ...           ...        ...        ...
# 9756        75.00        None             3       2007       None
# 9757        85.00  2020-02-01             3       2014       None
# 9758        53.30  2020-05-01             3       1973   miejskie
# 9759        90.25        None             4       2021   miejskie
# 9760        85.57        None             4       2020   miejskie
# 9761       104.35        None             4       None   miejskie
# 9762        52.50  2020-07-31             2       2006   miejskie
# 9763       134.40  2019-01-01             4       2000   miejskie
# 9764        83.70        None             3       2008       None
# 9765        33.00        None             2       2020   miejskie
# 9766        31.45        None             2       2020       None
# 9767        56.20        None             2       2013       None
# 9768        40.74        None             2       None   miejskie
# 9769        50.42        None             3       2021       None
# 9770        80.00        None             3       None     gazowe
# 9771        32.82  2020-05-18             2       2020   miejskie
# 9772        46.20  2020-06-01             3       1980   miejskie
# 9773        73.00        None             4       2019   miejskie
# 9774        94.40        None             4       2019       None
# 9775        64.00        None             3       1977       None
# 9776        30.00  2020-05-27             1       1977       None
# 9777        99.52        None             4       2017   miejskie
# 9778        61.37        None             2       2020       None
# 9779        38.50        None             2       2020       None
# 9780        73.00        None             4       1990   miejskie
# 9781        39.93        None             2       2020       None
# 9782        35.17  2021-05-01             2       2021   miejskie
# 9783        62.00        None             3       1985       None
# 9784        63.00        None             2       2017   miejskie
# 9785        62.57        None             3       None       None
#
#                      Lat                 Lon Distance_to_PKIN_in_km  \
# 0             52.3412347          20.9409258                16.2449
# 1             52.2534414           20.911715                 8.4505
# 2             52.2319581          21.0067249                    NaN
# 3             52.2668547          20.9727739                 5.1700
# 4             52.2319581          21.0067249                    NaN
# 5             52.1755092          20.9979059                 7.4484
# 6             52.3467073          20.9566364                15.9660
# 7     52.251869049999996  21.202865677042325                18.4464
# 8             52.2319581          21.0067249                    NaN
# 9               52.19021          20.9007185                 9.9699
# 10            52.2210608          20.9852995                 2.2267
# 11            52.2319581          21.0067249                    NaN
# 12            52.2319581          21.0067249                    NaN
# 13            52.2020512          21.1540425                14.6617
# 14            52.2573948          20.9592623                 5.0781
# 15            52.2319581          21.0067249                    NaN
# 16            52.2319581          21.0067249                    NaN
# 17            52.2319581          21.0067249                    NaN
# 18            52.2319581          21.0067249                    NaN
# 19            52.2222606          21.1006729                 9.4966
# 20            52.2319581          21.0067249                    NaN
# 21            52.2319581          21.0067249                    NaN
# 22            52.2319581          21.0067249                    NaN
# 23            52.2319581          21.0067249                    NaN
# 24            52.2530471          20.9272959                 7.8266
# 25            52.1432219          21.0322289                11.4678
# 26            52.2319581          21.0067249                    NaN
# 27            52.3399545          20.9390151                16.4593
# 28            52.2157279          21.0459129                 5.1325
# 29            52.2401678           20.993068                 1.7642
# ...                  ...                 ...                    ...
# 9756          52.2319581          21.0067249                    NaN
# 9757          52.2319581          21.0067249                    NaN
# 9758          52.1824732          21.0466807                 7.1824
# 9759          52.2319581          21.0067249                    NaN
# 9760          52.2317449          20.8939344                12.7456
# 9761          52.2285265          21.0111063                 1.5685
# 9762          52.2436362          21.1974631                18.0762
# 9763           52.279169          20.9867056                 6.4470
# 9764          52.2067242          20.9202755                 8.0850
# 9765          52.2212726          20.9297356                 5.9055
# 9766          52.1969746          20.9526451                 6.4376
# 9767          52.2319581          21.0067249                    NaN
# 9768          52.3385824          21.0535634                17.6723
# 9769          52.1704192          20.9935658                 8.0991
# 9770          52.2180608          20.9927854                 2.6392
# 9771          52.3393125          20.9496197                15.5797
# 9772          52.2404794          20.9636462                 4.2614
# 9773          52.2319581          21.0067249                    NaN
# 9774          52.2319581          21.0067249                    NaN
# 9775           52.270489          21.0542587                 7.7263
# 9776          52.1932576          20.8681838                13.2826
# 9777           52.157869          21.0807072                12.0691
# 9778          52.2634539          21.0453302                 6.2055
# 9779          52.1851429          21.0519214                 7.4956
# 9780          52.2357939          21.0818947                 9.0121
# 9781          52.2319581          21.0067249                    NaN
# 9782             52.2458          21.1335236                12.9749
# 9783           52.313793          20.9623343                12.0100
# 9784          52.1764707          21.0409812                 7.8762
# 9785          52.2399737          21.0123179                 1.6938
#
#      Time_to_PKIN_in_minutes
# 0                  22.551667
# 1                  14.270000
# 2                        NaN
# 3                   7.865000
# 4                        NaN
# 5                  10.970000
# 6                  21.930000
# 7                  24.715000
# 8                        NaN
# 9                  13.946667
# 10                  4.136667
# 11                       NaN
# 12                       NaN
# 13                 19.121667
# 14                  8.515000
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                 12.751667
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                 13.318333
# 25                 16.268333
# 26                       NaN
# 27                 22.876667
# 28                  8.866667
# 29                  3.200000
# ...                      ...
# 9756                     NaN
# 9757                     NaN
# 9758               12.263333
# 9759                     NaN
# 9760               15.260000
# 9761                3.500000
# 9762               24.168333
# 9763               10.020000
# 9764               12.201667
# 9765                9.771667
# 9766               10.895000
# 9767                     NaN
# 9768               22.285000
# 9769               12.066667
# 9770                4.825000
# 9771               21.603333
# 9772                7.985000
# 9773                     NaN
# 9774                     NaN
# 9775               12.500000
# 9776               18.421667
# 9777               16.968333
# 9778                9.901667
# 9779               12.310000
# 9780               11.395000
# 9781                     NaN
# 9782               16.276667
# 9783               16.941667
# 9784               11.971667
# 9785                3.493333
#
# [9786 rows x 22 columns]

# %%
df_final["Distance_to_PKIN_in_km"] = df_final.groupby('District')['Distance_to_PKIN_in_km'].apply(lambda x:x.fillna(x.mean()))

# %%
df_final["Time_to_PKIN_in_minutes"] = df_final.groupby('District')['Time_to_PKIN_in_minutes'].apply(lambda x:x.fillna(x.mean()))

# %%
df_final = df_final.loc[df_final["Distance_to_PKIN_in_km"].isna() == False]

# %%
df_final.reset_index(inplace = True, drop = True)

# %% [markdown]
# ### Creating final version of dataframe

# %%
df_to_save = df_final.copy()

# %%
df_to_save.drop(columns = ["Detailed_location_full", "Dostępne od", "Okna", "Materiał budynku"], inplace = True)

# %%
df_to_save.rename(columns = {"Dates_from_initial_announcement": "Days_from_initial_announcement"}, inplace = True)

# %%
df_to_save.to_excel("df_final.xlsx", index = False)
