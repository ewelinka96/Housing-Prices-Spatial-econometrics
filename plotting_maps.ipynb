# %%
import pandas as pd
import geopandas as gpd

# %%
df = gpd.read_file(r"C:\Users\grzeg\Desktop\studia\Data Science\2 rok\semestr 2\Spatial\project\shapefile\dzielnice_Warszawy.shp", encoding = 'utf-8')

# %%
df
# Out:
#         nazwa_dzie                                           geometry
# 0         Żoliborz  POLYGON ((633539.527 490793.934, 633542.003 49...
# 1   Praga-Południe  POLYGON ((643637.355 486100.653, 643623.409 48...
# 2          Mokotów  POLYGON ((638075.459 484924.185, 638083.540 48...
# 3             Wola  POLYGON ((635178.545 489906.766, 635181.466 48...
# 4          Wilanów  POLYGON ((643831.799 482999.436, 643838.935 48...
# 5           Wesoła  POLYGON ((649656.782 487878.522, 649437.965 48...
# 6            Wawer  POLYGON ((644054.020 482432.971, 644051.556 48...
# 7           Włochy  POLYGON ((631133.767 484862.977, 631146.760 48...
# 8          Ursynów  POLYGON ((635835.113 479216.177, 635867.908 47...
# 9      Śródmieście  POLYGON ((640812.855 485462.412, 640802.548 48...
# 10    Praga-Północ  POLYGON ((636803.980 491016.259, 636800.635 49...
# 11           Ursus  POLYGON ((628318.277 484272.087, 628294.222 48...
# 12        Targówek  POLYGON ((640534.075 495600.452, 640536.207 49...
# 13       Rembertów  POLYGON ((646100.072 492443.148, 646561.450 49...
# 14          Ochota  POLYGON ((636679.148 486516.728, 636690.549 48...
# 15         Bielany  POLYGON ((631143.045 497629.557, 631144.897 49...
# 16       Białołęka  POLYGON ((637217.031 493940.386, 637214.845 49...
# 17          Bemowo  POLYGON ((628834.626 492175.008, 628835.769 49...
